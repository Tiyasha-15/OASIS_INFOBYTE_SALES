# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("advertising.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
#  **Find the Null Value**

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# **Find the correlation between the attributes**

# %%
sns.heatmap(df.corr() , annot =True)
# Out:
# <Axes: >

# %% [markdown]
# **Scatterplot between TV and Sales**

# %%
sns.scatterplot(df, x="TV",y="Sales")
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %% [markdown]
# **Scatterplot Between Radio and Sales**

# %%
sns.scatterplot(df, x="Radio",y="Sales")
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %% [markdown]
# **Scatterplot Between Newspaper and Sales**

# %%
sns.scatterplot(df, x="Newspaper",y="Sales")
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %% [markdown]
# **Train the full dataset with respect to Sales with Linear Regression**

# %%
X = df.drop(["Sales"],axis =1)
y = df["Sales"]
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size = 0.3)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
p_test = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.9237253030008286

# %%
p_train = model.predict(X_train)

# %% [markdown]
# **Calculate Mean Squared Error**

# %%
mean_squared_error(y_train, p_train)
# Out:
# 2.8639711847582556

# %%
mean_squared_error(y_test, p_test)
# Out:
# 2.3858970995364497

# %% [markdown]
# **Calculate r2 score**

# %%
r2_score(y_train, p_train)
# Out:
# 0.8907473934070901

# %%
r2_score(y_test, p_test)
# Out:
# 0.9237253030008286

# %% [markdown]
# **Built a model only TV data with respect to Sales data with Linear Regression**

# %%
X = df[["TV"]]
y = df["Sales"]
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size = 0.3)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
p_test = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8122805147491627

# %%
p_train = model.predict(X_train)

# %% [markdown]
# **Calculate Mean Squared Error**

# %%
mean_squared_error(y_train, p_train)
# Out:
# 5.070595812201113

# %%
mean_squared_error(y_test, p_test)
# Out:
# 5.613131210681946

# %% [markdown]
# **Calculate r2 score**

# %%
r2_score(y_train, p_train)
# Out:
# 0.809975605734085

# %%
r2_score(y_test, p_test)
# Out:
# 0.8122805147491627

# %%
plt.figure(figsize=(17,6))
plt.scatter(X_train, y_train)
plt.plot(X_train, p_train, 'r')
plt.show()

# %% [markdown]
# **Built a model only Radio data with respect to Sales data with Linear Regression**

# %%
X = df[["Radio"]]
y = df["Sales"]
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size = 0.3)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
p_test = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.13969372809420855

# %%
p_train = model.predict(X_train)

# %%
p_train = model.predict(X_train)

# %% [markdown]
# **Calculate Mean Squared Error**

# %%
mean_squared_error(y_train, p_train)
# Out:
# 23.426828278773115

# %%
mean_squared_error(y_test, p_test)
# Out:
# 26.7113889547817

# %% [markdown]
# **Calculate r2 score**

# %%
r2_score(y_train, p_train)
# Out:
# 0.10757257252959762

# %%
r2_score(y_test, p_test)
# Out:
# 0.13969372809420855

# %%
plt.figure(figsize=(17,6))
plt.scatter(X_train, y_train)
plt.plot(X_train, p_train , "black")
plt.show()

# %% [markdown]
# **Built a model only Newspaper data with respect to Sales data with Linear Regression**

# %%
X = df[["Newspaper"]]
y = df["Sales"]
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size = 0.3)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
p_test = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.02576730390172477

# %%
p_train = model.predict(X_train)

# %%
p_train = model.predict(X_train)

# %% [markdown]
# **Calculate Mean Squared Error**

# %%
mean_squared_error(y_train, p_train)
# Out:
# 23.80667256545471

# %%
mean_squared_error(y_test, p_test)
# Out:
# 35.09029211633838

# %% [markdown]
# **Calculate r2 score**

# %%
r2_score(y_train, p_train)
# Out:
# 0.013265431908942471

# %%
r2_score(y_test, p_test)
# Out:
# 0.02576730390172477

# %%
plt.figure(figsize=(17,6))
plt.scatter(X_train, y_train)
plt.plot(X_train, p_train , "black")
plt.show()
